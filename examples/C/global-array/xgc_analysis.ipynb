# %%
 # %matplotlib notebook
from __future__ import division
import numpy as np
import adios as ad
import matplotlib.pyplot as plt

# %%
fmesh = ad.file('xgc.mesh.bp')
rz = fmesh['/coordinates/values'][:]
conn = fmesh['/cell_set[0]/node_connect_list'][:]
R = rz[:,0]
Z = rz[:,1]

# %%
plt.figure(2)
plt.triplot(R, Z, conn);
# Out:
# <img src="data:image/png;base64,...">

# %%
f = ad.file('xgc.3d.08000.bp')
## '0' plane only
dpot = f['dpot'][:,0]
fmesh = ad.file('xgc.mesh.bp')
rz = fmesh['/coordinates/values'][:]
conn = fmesh['/cell_set[0]/node_connect_list'][:]
R = rz[:,0]
Z = rz[:,1]

# %%
plt.figure(10, figsize=(12,9))
plt.rc('xtick', labelsize=26)          # fontsize of the tick labels
plt.rc('ytick', labelsize=26)   

axis_font = {'fontname':'Arial', 'size':'38'}

plt.xlabel('R', **axis_font)
plt.ylabel('Z',**axis_font )
plt.tricontourf(R, Z, conn, dpot,cmap=plt.cm.jet, levels=np.linspace(-76,71,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
fg = ad.file('data1/xgc.3d.08000.bp')
rl0 = fg['R/L1'][:]
zl0 = fg['Z/L1'][:]
connl0 = fg['mesh/L1'][:]
delta=fg['dpot/L1'][:]
plt.figure(11,figsize=(12,9))
plt.xlabel('R', **axis_font)
plt.ylabel('Z',**axis_font )
plt.tricontourf(rl0, zl0, connl0, delta, cmap=plt.cm.jet,levels=np.linspace(-76,71,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
fg = ad.file('data0/dpot.bp')
rl0 = fg['R/L0'][:]
zl0 = fg['Z/L0'][:]
connl0 = fg['mesh/L0'][:]
delta=fg['delta/L0'][:]
plt.figure(12)
plt.tricontourf(rl0, zl0, connl0, delta, cmap=plt.cm.jet,levels=np.linspace(-75,70,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
fg = ad.file('data1/dpot.bp')
dpotl1 = fg['dpot/L1'][:]
rl1 = fg['R/L1'][:]
zl1 = fg['Z/L1'][:]
connl1 = fg['mesh/L1'][:]
plt.figure(3, figsize=(8,6))
plt.rc('xtick', labelsize=18)          # fontsize of the tick labels
plt.rc('ytick', labelsize=18)   

axis_font = {'fontname':'Arial', 'size':'18'}

plt.xlabel('R', **axis_font)
plt.ylabel('Z',**axis_font )
plt.title('dpot', **axis_font)

plt.tricontourf(rl1, zl1, connl1, dpotl1,cmap=plt.cm.jet, levels=np.linspace(-76,71,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
fg = ad.file('data1/dpot.bp.dir/dpot.bp.1')
dpotl1 = fg['dpot/L1'][:]
rl1 = fg['R/L1'][:]
zl1 = fg['Z/L1'][:]
connl1 = fg['mesh/L1'][:]
plt.figure(4)
plt.tricontourf(rl1, zl1, connl1, dpotl1,cmap=plt.cm.jet);
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure(7)
plt.tricontourf(rl0, zl0, connl0, full_field, cmap=plt.cm.jet,levels=np.linspace(-75,70,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">

# %%
fg = ad.file('data2/dpot.bp')
dpotl2 = fg['dpot/L2'][:]
rl2 = fg['R/L2'][:]
zl2 = fg['Z/L2'][:]
connl2 = fg['mesh/L2'][:]

# %%
plt.figure(5)
plt.tricontourf(rl2, zl2, connl2, dpotl2, cmap=plt.cm.jet,levels=np.linspace(-75,70,num=250));
plt.colorbar();
# Out:
# <img src="data:image/png;base64,...">
